# %%
import pandas as pd
import numpy as np

# %%
# TABELA B1 referente a tripulação simples HORA ACLIMATADA
# quando o valor for de dois digitos e terminar com 9, significa por exemplo (6,69) das 6 horas até 6:50, 
# quando o valor for de dois digitos e terminar em 9, significa por exemplo (13,95) 13 horas de jornada e 9 horas e meia de voo


# TABELA B2 referente a tripulação de cabine composta ou revezamento HORA ACLIMATADA
# PARA TIPO DE ACOMODAÇÃO, A CLASSE 1 = '1', CLASSE 2 = '2' E CLASSE 3 = '3'
# PARA TIPO DE TRIPULAÇÃO, COMPOSTA = '2', REVEZAMENTO = '3'
# horário, classe de acomodação, tipo de tripulação, jornada e tempo de voo
tabelaB3 = np.array([[[[6,659],[1,1],[2,2],[15,139], [6,659],[1,1],[3,3],[17,159], [6,659],[2,2],[2,2],[15,1359], [6,659],[2,2],[3,3],[17,159], [6,659],[3,3],[2,2],[14,129], [6,659],[3,3],[3,3],[16,149]],\
                     [[7,1359],[1,1],[2,2],[16,149], [7,1359],[1,1],[3,3],[18,169], [7,1359],[2,2],[2,2],[16,1459], [7,1359],[2,2],[3,3],[18,169], [7,1359],[3,3],[2,2],[15,139], [7,1359],[3,3],[3,3],[17,159]],\
                     [[14,1759],[1,1],[2,2],[15,139], [14,1759],[1,1],[3,3],[17,159], [14,1759],[2,2],[2,2],[15,1359], [14,1759],[2,2],[3,3],[17,159], [14,1759],[3,3],[2,2],[14,129], [14,1759],[3,3],[3,3],[16,149]],\
                     [[18,559],[1,1],[2,2],[14,129], [18,559],[1,1],[3,3],[16,149], [18,559],[2,2],[2,2],[14,125], [18,559],[2,2],[3,3],[16,145], [18,559],[3,3],[2,2],[13,119], [18,559],[3,3],[3,3],[14,129]]]])  

# TABELA C1 referente a tripulação simples OPERAÇÃO NÃO COMPLEXA
# quando o valor for de dois digitos e terminar com 9, significa por exemplo (6,69) das 6 horas até 6:50, 
# quando o valor for de dois digitos e terminar em 9, significa por exemplo (13,95) 13 horas de jornada e 9 horas e meia de voo
tabelaC1 = np.array([[[6,69],[1, 2],[11,9],[6,69],[3, 4],[11,9], [6,69],[5, 5],[10,8], [6,69],[6, 6],[9,8], [6,69],[7, 7],[9,8]],\
                      [[7,69],[1, 2],[13,95],[7,69],[3, 4],[12,9], [7,69],[5, 5],[11,9], [7,69],[6, 6],[10,8], [7,69],[7, 7],[9,8]],\
                      [[8,119],[1, 2],[13,10],[8,119],[3, 4],[13,99], [8,119],[5, 5],[12,9], [8,119],[6, 6],[11,9], [8,119],[7, 7],[10,8]],\
                      [[12,139],[1, 2],[13,95],[12,139],[3, 4],[12,95], [12,139],[5, 5],[11,9], [12,139],[6, 6],[10,8], [12,139],[7, 7],[9,8]],\
                      [[14,159],[1, 2],[11,9],[14,159],[3, 4],[11,9], [14,159],[5, 5],[10,8], [14,159],[6, 6],[9,8], [14,159],[7, 7],[9,8]],\
                      [[16,179],[1, 2],[10,8],[16,179],[3, 4],[10,8], [16,179],[5, 5],[9,8], [16,179],[6, 6],[9,8], [16,179],[7, 7],[9,8]],\
                      [[18,559],[1, 2],[9,8],[18,559],[3, 4],[9,8], [18,559],[5, 5],[9,7], [18,559],[6, 6],[9,7], [18,559],[7, 7],[9,7]]])

#
# TABELA B2 referente a tripulação técnica composta ou revezamento HORA ACLIMATADA
# PARA TIPO DE ACOMODAÇÃO, A CLASSE 1 = '1', CLASSE 2 = '2' E CLASSE 3 = '3'
# PARA TIPO DE TRIPULAÇÃO, COMPOSTA = '2', REVEZAMENTO = '3'
# horário, classe de acomodação, tipo de tripulação, jornada e tempo de voo
tabelaB2 = np.array([[[[6,659],[1,1],[2,2],[15,135], [6,659],[1,1],[3,3],[17,155], [6,659],[2,2],[2,2],[14,125], [6,659],[2,2],[3,3],[16,145], [6,659],[3,3],[2,2],[13,115], [6,659],[3,3],[3,3],[14,125]],\
                     [[7,1359],[1,1],[2,2],[16,145], [7,1359],[1,1],[3,3],[18,165], [7,1359],[2,2],[2,2],[15,135], [7,1359],[2,2],[3,3],[17,155], [7,1359],[3,3],[2,2],[14,125], [7,1359],[3,3],[3,3],[15,135]],\
                     [[14,1759],[1,1],[2,2],[15,135], [14,1759],[1,1],[3,3],[17,155], [14,1759],[2,2],[2,2],[14,125], [14,1759],[2,2],[3,3],[16,145], [14,1759],[3,3],[2,2],[13,115], [14,1795],[3,3],[3,3],[14,125]],\
                     [[18,559],[1,1],[2,2],[14,125], [18,559],[1,1],[3,3],[16,145], [18,559],[2,2],[2,2],[13,115], [18,559],[2,2],[3,3],[14,125], [18,559],[3,3],[2,2],[12,109], [18,559],[3,3],[3,3],[13,115]]]])  

tabelaB1 = np.array([[[6,659],[1, 2],[11,9],[6,69],[3, 4],[11,9], [6,69],[5, 5],[10,8], [6,69],[6, 6],[9,8], [6,69],[7, 7],[9,8]],\
                      [[7,659],[1, 2],[13,95],[7,69],[3, 4],[12,9], [7,69],[5, 5],[11,9], [7,69],[6, 6],[10,8], [7,69],[7, 7],[9,8]],\
                      [[8,1159],[1, 2],[13,10],[8,119],[3, 4],[13,95], [8,119],[5, 5],[12,9], [8,119],[6, 6],[11,9], [8,119],[7, 7],[10,8]],\
                      [[12,1359],[1, 2],[12,95],[12,1359],[3, 4],[12,9], [12,1359],[5, 5],[11,9], [12,1359],[6, 6],[10,8], [12,1359],[7, 7],[9,8]],\
                      [[14,1559],[1, 2],[11,9],[14,1559],[3, 4],[12,9], [14,1559],[5, 5],[10,8], [14,1559],[6, 6],[9,8], [14,1559],[7, 7],[9,8]],\
                      [[16,1759],[1, 2],[10,8],[16,1759],[3, 4],[10,8], [16,1759],[5, 5],[9,8], [16,1759],[6, 6],[9,8], [16,1759],[7, 7],[9,8]],\
                      [[18,659],[1, 2],[9,8],[18,659],[3, 4],[9,8], [18,659],[5, 5],[9,7], [18,659],[6, 6],[9,7], [18,659],[7, 7],[9,7]]])

# %% [markdown]
# TABELA B2
# SEGUNDO DIGITO, ACESSA A LINHA  '0' >> (O HORÁRIO DAS 06:00 ATÉ 06:59), '1' >> (HORÁRIO DAS 07:13:59)
#
# TERCEIRO DIGITO, ACESSA

# %%
lim_voo_revezamento_classe3 = str(tabelaB1[1,5,0])
#lim_voo_revezamento_classe3_final = (lim_voo_revezamento_classe3[0:2], ': ', '30')
print(lim_voo_revezamento_classe3)
# Out:
# 12
